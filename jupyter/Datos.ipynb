# %%
import matplotlib.pyplot as plt

data1 = ['Martin','max','Seiryu','Ifran','kishiro','unori','Belén','Kathy','Maxi','Miki']
data2 = [14,77,38,17,41,40,142,71,53,48]
data3 = [23,51,20,13,27,19,44,28,77,17]
plt.title("Nivel 1")
plt.plot(data1,data2,data3, marker = 'o')
plt.xlabel("Jugadores", color = 'blue')
plt.ylabel("Segundos \n cantidad de movimientos", color = 'blue')
plt.plot(data2,label="Segundos")
plt.plot(data3,label="Cantidad de Movimientos")
plt.scatter(data1,data2,data3)

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

Jugadores = ['Martin','max','Seiryu','Ifran','kishiro','unori','Belén','Kathy','Maxi','Miki']
Tiempo = [27,61,86,94,130,86,109,68,59,145]
Movimientos = [23,27,49,33,30,23,31,62,31,62]
plt.title("Nivel 2")
plt.plot(Jugadores,Tiempo,Movimientos, marker = 'o')
plt.xlabel("Jugadores", color = 'blue')
plt.ylabel("Segundos \n cantidad de movimientos", color = 'blue')
plt.plot(Tiempo,label="Segundos")
plt.plot(Movimientos,label="Cantidad de Movimientos")
plt.scatter(Jugadores,Tiempo,Movimientos)

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

Jugadores = ['Martin','Seiryu','Ifran','kishiro','unori','Belén','Kathy','Maxi','Miki']
Tiempo = [41,329,116,127,121,329,131,170,152]
Movimientos = [18,89,21,48,41,68,58,42,36]
plt.title("Nivel 3")
plt.plot(Jugadores,Tiempo,Movimientos, marker = 'o')
plt.xlabel("Jugadores", color = 'blue')
plt.plot(Tiempo,label="Segundos")
plt.plot(Movimientos,label="Cantidad de Movimientos",)
plt.ylabel("Segundos \n cantidad de movimientos", color = 'blue')
plt.scatter(Jugadores,Tiempo,Movimientos)
plt.legend(loc='upper right', bbox_to_anchor=(1.5,0.5))
plt.show()

# %%
import matplotlib.pyplot as plt

Jugadores = ['Martin','Seiryu','Ifran','kishiro','Belén','Kathy','Maxi','Miki']
Tiempo = [46,143,168,178,156,98,93,188]
Movimientos = [13,16,20,14,13,20,21,24]
plt.title("Nivel 4")
plt.plot(Jugadores,Tiempo,Movimientos, marker = 'o')
plt.xlabel("Jugadores", color = 'blue')
plt.ylabel("Segundos \n cantidad de movimientos", color = 'blue')
plt.plot(Tiempo,label="Segundos")
plt.plot(Movimientos,label="Cantidad de Movimientos",)
plt.scatter(Jugadores,Tiempo,Movimientos)
plt.legend(loc='upper right', bbox_to_anchor=(1.5,0.5))
plt.show()

# %%
import matplotlib.pyplot as plt

Jugadores = ['Martin','Seiryu','Ifran','kishiro','Belén','Kathy','Maxi','Miki']
Tiempo = [61,489,332,197,590,180,248,226]
Movimientos = [19,29,49,33,33,45,19,22]
plt.title("Nivel 5")
plt.plot(Jugadores,Tiempo,Movimientos, marker = 'o')
plt.xlabel("Jugadores", color = 'blue')
plt.ylabel("Segundos \n cantidad de movimientos", color = 'blue')
plt.plot(Tiempo,label="Segundos")
plt.plot(Movimientos,label="Cantidad de Movimientos",)
plt.scatter(Jugadores,Tiempo,Movimientos)
plt.legend(loc='upper right', bbox_to_anchor=(1.5,0.5))
plt.show()

# %%
import matplotlib.pyplot as plt

Jugadores = ['Martin','Seiryu','Ifran','kishiro','Belén','Kathy','Maxi','Miki']
Tiempo = [61,489,332,197,590,180,248,226]
Movimientos = [19,29,49,33,33,45,19,22]
plt.title("Nivel 5")
plt.plot(Jugadores,Tiempo,Movimientos, marker = 'o')
plt.xlabel("Jugadores", color = 'blue')
plt.plot(Tiempo,label="Segundos")
plt.plot(Movimientos,label="Cantidad de Movimientos",)
plt.ylabel("Segundos \n cantidad de movimientos", color = 'blue')
plt.scatter(Jugadores,Tiempo,Movimientos)
plt.legend(loc='upper right', bbox_to_anchor=(1.5,0.5))
plt.show()
